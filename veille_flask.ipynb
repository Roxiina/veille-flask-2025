# %% [markdown]
# # 🔎 Veille technologique – Flask (2025)
#
# ## 1. Flask 3.1.1 – Correctif de sécurité CVE-2025-47278
# 🔗 [Release Flask 3.1.1](https://github.com/pallets/flask/releases/tag/3.1.1)
# 💡 Cette version corrige une vulnérabilité critique liée à la gestion des clés de repli (`SECRET_KEY_FALLBACKS`).
# Elle permettait potentiellement l’utilisation de clés périmées pour signer des sessions.
# Ce correctif illustre l’importance de maintenir ses dépendances à jour pour éviter des failles de sécurité.
#
# ---
#
# ## 2. Changement majeur dans SQLAlchemy 2.0 et Flask-SQLAlchemy
# 🔗 [Documentation Flask-SQLAlchemy – Queries](https://flask-sqlalchemy.palletsprojects.com/en/3.1.x/queries/#select)
# 💡 L’API `Query` est désormais considérée comme "legacy" dans SQLAlchemy 2.0.
# Les développeurs doivent migrer vers l’usage explicite de `select()` pour leurs requêtes ORM.
# Cela implique une adaptation du code existant mais améliore la lisibilité et la modernité du code.
#
# ---
#
# ## 3. Documentation officielle Flask
# 🔗 [Site officiel Flask](https://flask.palletsprojects.com)
# 💡 La documentation officielle reste une référence incontournable.
# Elle couvre les concepts clés comme le serveur de développement, le débogueur, et le moteur de templates Jinja2.
# Indispensable pour toute veille technique.
#
# ---
#
# ## 4. Compatibilité et dépendances dans l’écosystème Flask
# 🔗 [Commit GitHub – Fix dépendance Flask-Login](https://github.com/pallets/flask/commit/7d98a49bc38d0849367b348bfe37a2b689323419)
# 💡 Ce commit illustre les problèmes de compatibilité rencontrés lors des mises à jour majeures (Flask 3.0 et Werkzeug 3.0).
# Certaines extensions populaires comme Flask-Login ont subi des ruptures de compatibilité.
# Cela rappelle l’importance de surveiller l’écosystème d’extensions.
#
# ---
#
# ## 5. Intégration de Bootstrap avec Flask
# 🔗 [Bootstrap 4.3.1 – CDN CSS](https://stackpath.bootstrapcdn.com/bootstrap/4.3.1/css/bootstrap.min.css)
# 💡 Flask se concentre sur le backend mais son association avec Bootstrap permet de créer rapidement des interfaces modernes et responsives.
# Idéal pour le prototypage rapide.
#
# ---
#
# ## 6. Construire une API REST avec Flask-Restful
# 🔗 [Guide REST API avec Flask](https://www.analyticsvidhya.com/blog/2022/01/rest-api-with-python-and-flask/)
# 💡 Ce guide explique comment concevoir une API REST avec Flask-Restful.
# Utile pour créer rapidement des services web.
# Cependant, FastAPI est souvent préféré en 2025 pour les performances et l’async natif.
#
# ---
#
# ## 7. Comparaison avec d’autres frameworks backend
# 🔗 [Python vs Node.js – Comparatif Frameworks](https://ingeniousmindslab.com/blogs/python-vs-node-best-backend-framework/)
# 💡 Cet article situe Flask dans l’écosystème backend.
# S’il reste très adapté pour des microservices et du prototypage, il est concurrencé par FastAPI (performance) et Django (framework complet).
#
# ---
#
# # ✅ Conclusion
# - Vigilance forte sur la sécurité.
# - Migration nécessaire vers SQLAlchemy 2.0.
# - Problèmes de compatibilité possibles avec les extensions.
# - Intégration facilitée avec Bootstrap pour le frontend.
# - Flask reste pertinent mais challengé par FastAPI et Django.
